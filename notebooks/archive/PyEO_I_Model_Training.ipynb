# %% [markdown]
# # PyEO: How to train your classifier..

# %% [markdown]
# **Table of Contents**<a id='toc0_'></a>
# - [How to Delineate Sample Areas (in QGIS)](#toc1_)
#   - [Heiko's Instructional Video](#toc1_1_)
#   - [Matt's Instructional Video](#toc1_2_)
#     - [Written QGIS Tips](#toc1_2_1_)
# - [Setting up the Notebook](#toc2_)
#   - [Import the Required Libraries](#toc2_1_)
#   - [Specify the Root Directory](#toc2_2_)
#   - [Initialise the Logger](#toc2_3_)
# - [Single Tile Approach](#toc3_)
#   - [Extract Spectral Information from Sentinel-2 Imagery](#toc3_1_)
#     - [Create `out_folder` if it does not exist](#toc3_1_1_)
#     - [Run `extract_features_to_csv`](#toc3_1_2_)
#   - [Model Creation and Training](#toc3_2_)
#   - [Accuracy Statistics](#toc3_3_)
#   - [Imagery Classification](#toc3_4_)
#   - [Visualise the Classified Imagery](#toc3_5_)
# - [Multiple Tile and Training Shapefiles Approach](#toc4_)
#   - [Classify Directory](#toc4_1_)
#   - [Visualise the Classifications](#toc4_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# In the previous notebook, we queried and downloaded Sentinel-2 imagery. Now, we need to create a model to classify the land cover (and thus detect changes in forest cover between two date periods).
#
# To build a model, we will need training data. For PyEO, we define training data as pixel surface reflectance values and their corresponding land cover classes.
#
# The section below details how to delineate training polygons in QGIS, but if you already have training data stored as a shape file, then you can skip and proceed to [importing the pyeo library](#Import-the-Required-Libraries).

# %% [markdown]
# # <a id='toc1_'></a>[How to Delineate Sample Areas using QGIS](#toc0_)

# %% [markdown]
# ## <a id='toc1_1_'></a>[Heiko's Instructional Video](#toc0_)

# %% [markdown]
# The below recording is from Prof. Heiko Balzter. Here Heiko takes users through the process of creating shapefiles over Sentinel-2 imagery.
#
# You may need to close the file manager tab to the left of this notebook, to see the embedded video more clearly.

# %%
# Heiko's training sample delineation over Rutland, UK.
from IPython.display import HTML

# Note: On the HPC, the below output is black (probably a firewall restriction)
# On sepal, the video plays.
HTML('<iframe width="1080" height="490" src="https://leicester.cloud.panopto.eu/Panopto/Pages/Viewer.aspx?id=a4568baf-c85d-4fab-b6c4-ac9300ed6ab2" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1080" height="490" src="https://leicester.cloud.panopto.eu/Panopto/Pages/Viewer.aspx?id=a4568baf-c85d-4fab-b6c4-ac9300ed6ab2" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## <a id='toc1_2_'></a>[Matt's Instructional Video](#toc0_)

# %% [markdown]
# - TODO Matt to record a video delineating samples over Kenya covering these topics:
# - How to create a shapefile for sampling
# - The advised structure of the shapefile e.g. id, class
# - Digitising toolbars
# - How to delineate
# - Sample away from class edges
# - Reshape often
# - Send2GE plugin to inspect high-res imagery for uncertain land cover classes
# - Save often
# - Sample underrepresented classes more

# %% [raw]
# ## Summary of Training Data Specification Process
#
# ### TODO:
# - Add short text-based set of instructions on steps to to enter training polygons from the point of opening QGIS
#   - Name field as CODE etc.
# - Provide a set of standard styles under the QGIS/styles folder for report layers and for training classes
# - Add instructions on how to apply standard styles so that training regions are coloured by class in a consistent manner
# - Merge into QGIS Tips section below..
# - Including..
# - Need for added field to be integer, to be named 'class', need to add layer/shapefile, need to toggle editing of layer, need to save layer to model_dir

# %% [markdown]
# ### <a id='toc1_2_1_'></a>[QGIS Tips](#toc0_)

# %% [markdown]
# 1. Whilst in QGIS, make sure you have the **Digitizing** and **Advanced Digitizing** toolbars enabled. To do so, click:
#     - View > Toolbars > Tick Digitizing and Advanced Digitizing
#
# 2. To delineate features, use the **Add Polygon Feature** tool. It looks like this: ![image](./Create_polygon.PNG)
#
# 3. Avoid delineating near the edges of land cover, e.g. at the forest edge adjacent to a road. These edge pixels will capture the variation in land-cover at the sub-pixel level, confusing your classifier.
#
# 3. The **Reshape Features** tool, is extremely useful for extending already delineated polygons. Click inside the polygon you want to extend, then click any points outside of the polygon (covering your land cover class of interest), once ready - click inside the polygon to complete the loop, and right click to finish delineation. The tool icon looks like this: ![image](./Reshape_features.PNG)
#
# 4. Install Google Earth Pro on your PC, https://www.google.com/earth/about/versions/ , which offers very-high resolution satellite imagery, and Google StreetView, to help you understand the land covers you are delineating.
#
# 5. Install the QGIS plugin, **Send2GE**. This plugin sends your location directly to your installed Google Earth Pro. To do so, click on the Send2GE icon, ![image](./Send2GE.PNG), and then click on the location you want to view in Google Earth Pro.
#
# 6. Consider your Land Cover Classes and tailor them to what you want your product to achieve.
# Below are a list of classes that we have used for our `pyeo` classifier, but alternative classes may be more appropriate for your needs.
#
#     1 = Primary Forest
#     2. Plantation Forest
#     3. Bare Soil
#     4. Crops
#     5. Grassland
#     6. Open Water
#     7. Burn Scar
#     8. Cloud
#     9. Cloud Shadow
#     10. Haze
#     11. Sparse Woodland
#     12. Dense Woodland
#     13. Artificial

# %% [markdown]
# # <a id='toc2_'></a>[Setting up requirements to use this Notebook](#toc0_)

# %% [markdown]
# ## Select the pyeo_env conda environment
# - Use the drop-down list at the top right of the Jupyter notebook window
# - If pyeo_env is not available in the list please open pyeo_Setup.ipynb and follow the instructions to install it.

# %% [markdown]
# ## <a id='toc2_1_'></a>[Import the Required Libraries](#toc0_)

# %% [markdown]
# Before proceeding, let's check that the import statements from pyeo execute correctly.

# %%
import os
from pathlib import Path
from pyeo import classification as cls
from pyeo import filesystem_utilities as file_utils
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import ensemble as ens
import numpy as np
import joblib

print("Library imports complete")
# Out:
# Library imports complete

# %% [markdown]
# ## Specify GDAL and PROJ Paths

# %% [markdown]
# Because we have installed our own versions of GDAL and PROJ through conda, and because incompatible versions are already installed on SEPAL, we need to specify our paths for GDAL and PROJ.

# %%
# amend this path to the name of your conda environment
conda_env_name = "pyeo_env"

# don't amend the below script unless it is necessary, and you know what you're doing
home = str(Path.home())
os.environ["GDAL_DATA"] = f"{home}/miniconda3/envs/{conda_env_name}/share/gdal"
os.environ["PROJ_LIB"] = f"{home}/miniconda3/envs/{conda_env_name}/share/proj"

# %% [markdown]
# ## <a id='toc2_2_'></a>[Specify the Root Directory](#toc0_)

# %% [markdown]
# This is the directory that you want to store your data under. The notebook will use this as the prefix for your training raster and training shapefile filenames.
#
# Change the path in the cell below to suit where you want your data to be stored under.
#
# TODO
# - Refer to pyeo_home instead to pyeo_dir to match code base
# - Define a local model_dir relative to pyeo_dir
# - Instruct user to create the model_training subdirectory and/or check it already exists

# %%
pyeo_dir = "/data/clcr/shared/IMPRESS/Ivan/20230524_pyeo_Test_Installation/code_folder/pyeo"
model_dir = "./models/model_all_bands"
log_dir = "./log"

os.chdir(pyeo_dir)
if not os.path.exists(model_dir): 
    os.mkdir(model_dir)
if not os.path.exists(log_dir): 
    os.mkdir(log_dir)

# %% [markdown]
# ## <a id='toc2_3_'></a>[Initialise the Logger](#toc0_)

# %% [markdown]
# When running `pyeo`, we record our processing efforts, parameters etc. in a log file (a .txt file). If we are ever curious about what `pyeo` has done and when, we can look at the log file.
# So below, we initialise our log file. Replace `log_path` with your own path.
#  **Note: the log.txt does not need to exist before running the function**

# %%
log_filename = "model_log.txt"
log = file_utils.init_log(os.path.join(log_dir, log_filename))

# Let's add some information to the log
log.info(f'pyeo_Model_Training Notebook Started:')
log.info(f'- conda_env_name set to: {conda_env_name}')
log.info(f'- pyeo_dir set to: {pyeo_dir}')
log.info(f'- model_dir set to: {model_dir}')
log.info(f'- log_dir set to: {log_dir}')
# Out:
# 2023-06-01 17:10:30,989: INFO: ****PROCESSING START****
# 2023-06-01 17:10:31,001: INFO: pyeo_Model_Training Notebook Started:
# 2023-06-01 17:10:31,002: INFO: - conda_env_name set to: pyeo_env
# 2023-06-01 17:10:31,004: INFO: - pyeo_dir set to: /data/clcr/shared/IMPRESS/Ivan/20230524_pyeo_Test_Installation/code_folder/pyeo
# 2023-06-01 17:10:31,005: INFO: - model_dir set to: ./models/model_all_bands
# 2023-06-01 17:10:31,006: INFO: - log_dir set to: ./log

# %% [markdown]
# Whenever a function writes to the log, the output will be displayed in the Python cell output, but the log file can also be viewed in a text editor.
# **Note, sometimes not all of the log file output in the cell outputs is displayed, so it is best to view the log.txt file in an external text editor.**

# %% [markdown]
# # Model Training and Classification, Step by Step

# %% [markdown]
# In this section, we will follow the individual steps to extract spectral information from the Sentinel-2 imagery using our training shapefiles, train a Random Forest model on the spectral values of the land cover classes, and classify a Sentinel-2 image tile.

# %% [markdown]
# ## <a id='toc3_1_'></a>[Extract Spectral Information from Sentinel-2 Imagery](#toc0_)

# %% [markdown]
# Since we have delineated our training polygons, we can now extract the spectral information from the imagery, by running `cls.extract_features_to_csv()` in the cell below.
# First, specify the paths to the training shapefile, training raster and the out directory.
#
# TODO
# - Specify that following paths are relative to model_dir

# %%
# specify the path of the training shapefile
training_shape_filename = "composite_T36NXG_20221202T075301_AllBands_clipped.shp"
# specify the path of the training raster
training_raster_filename = "composite_T36NXG_20221202T075301_AllBands_clipped.tif"
# specify the output folder
out_dir = model_dir
# specify the output filename for the model
model_name = "AllBands_model"
model_out_filename = f"{model_name}.pkl"
# specify the output filename for the csv
feature_out_filename = f'{model_name}_features.csv'

log.info(f'File and Folder Specification Started::')
log.info(f'- training_shape_filename set to: {training_shape_filename}')
log.info(f'- training_raster_filename set to: {training_raster_filename}')
log.info(f'- out_dir set to: {out_dir}')
log.info(f'- model_out_filename set to: {model_out_filename}')
log.info(f'- feature_out_filename set to: {feature_out_filename}')
# Out:
# 2023-06-01 17:11:00,862: INFO: File and Folder Specification Started::
# 2023-06-01 17:11:00,864: INFO: - training_shape_filename set to: composite_T36NXG_20221202T075301_AllBands_clipped.shp
# 2023-06-01 17:11:00,864: INFO: - training_raster_filename set to: composite_T36NXG_20221202T075301_AllBands_clipped.tif
# 2023-06-01 17:11:00,865: INFO: - out_dir set to: ./models/model_all_bands
# 2023-06-01 17:11:00,865: INFO: - model_out_filename set to: AllBands_model.pkl
# 2023-06-01 17:11:00,866: INFO: - feature_out_filename set to: AllBands_model_features.csv

# %% [markdown]
# ### <a id='toc3_1_1_'></a>[Create `out_folder` if it does not exist](#toc0_)

# %%
# if not os.path.exists(os.path.join(pyeo_home, out_folder)):
    # os.mkdir(os.path.join(pyeo_home, out_folder))

# %% [markdown]
# ### <a id='toc3_1_2_'></a>[Run `extract_features_to_csv`](#toc0_)

# %% [markdown]
# Now, we can run the `cls.extract_features_to_csv` function.
# If the column heading of your training shapefile is not `CODE`, substitute the correct column name with the `attribute` argument.

# %%
# declare our path variables as easier to read variables
out_path = os.path.join(out_dir, feature_out_filename)
training_raster_path = os.path.join(model_dir, training_raster_filename)
training_shapefile_path = os.path.join(model_dir, training_shape_filename)

log.info(f'Feature Extraction Started:')
log.info(f'- out_path set to: {out_path}')
log.info(f'- training_raster_path set to: {training_raster_path}')
log.info(f'- training_shapefile_path set to: {training_shapefile_path}')
# Out:
# 2023-06-01 17:22:46,851: INFO: Feature Extraction Started:
# 2023-06-01 17:22:46,852: INFO: - out_path set to: ./models/model_all_bands/AllBands_model_features.csv
# 2023-06-01 17:22:46,853: INFO: - training_raster_path set to: ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_clipped.tif
# 2023-06-01 17:22:46,853: INFO: - training_shapefile_path set to: ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_clipped.shp

# %%
# run the function to extract the spectral values and assigned classes from the training raster and training shapefile
cls.extract_features_to_csv(in_ras_path=training_raster_path,
                            training_shape_path=training_shapefile_path,
                            out_path=out_path,
                            attribute="class")
# Out:
# 2023-06-01 17:22:47,982: INFO: Get training data from ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_clipped.tif
# 2023-06-01 17:22:47,984: INFO:                    and ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_clipped.shp
# 2023-06-01 17:22:48,063: INFO: Shape raster path /lustre/alice3/data/clcr/shared/IMPRESS/Ivan/20230524_pyeo_Test_Installation/code_folder/pyeo/tmpmhkllb6h/composite_T36NXG_20221202T075301_AllBands_clipped_rasterised
# 2023-06-01 17:22:48,112: INFO: 12 bands in image file
# 2023-06-01 17:22:48,112: INFO: 110260 training pixels in shapefile

# %% [markdown]
# Let's see what `features.csv` looks like, by reading in the csv and printing the first 5 rows.
#
# Each row represents a pixel of a certain class. The first column in each row is the class of that pixel, with the columns after that being the Sentinel 2 blue, green, red and NIR value of that pixel.

# %%
# declare out_path from previous cell as csv_path, to avoid confusion
csv_path = out_path

# read in our spectral signatures
features = pd.read_csv(csv_path)

#TODO: No header flag

# prints the first 5 rows of features
features.head(5)
# Out:
#    3.0  339.0  568.0  896.0  1168.0  1533.0  2326.0  2595.0  2790.0  2827.0  \
# 0  3.0  339.0  518.0  792.0  1138.0  1499.0  2125.0  2327.0  2548.0  2510.0
# 1  3.0  366.0  434.0  738.0   941.0  1487.0  2337.0  2645.0  2944.0  2867.0
# 2  3.0  366.0  423.0  747.0   899.0  1487.0  2337.0  2645.0  2978.0  2867.0
# 3  3.0  339.0  507.0  790.0  1066.0  1533.0  2326.0  2595.0  2620.0  2827.0
# 4  3.0  339.0  450.0  677.0   936.0  1533.0  2326.0  2595.0  2592.0  2827.0
#
#    2418.0  2629.0  1855.0
# 0  2418.0  2499.0  1807.0
# 1  2551.0  2626.0  1817.0
# 2  2551.0  2626.0  1817.0
# 3  2418.0  2629.0  1855.0
# 4  2418.0  2629.0  1855.0

# %%
# Histogram to view class balance

# %% [markdown]
# ## <a id='toc3_2_'></a>[Model Creation and Training](#toc0_)

# %% [markdown]
# You can create a scikit-learn Extra Trees Classifier using pyeo with the code in the cell below:

# %%
# TODO Use pyeo function to balance training data
#https://github.com/eogit/pyeo/blob/master/pyeo/apps/model_creation/create_rf_model_from_region.py
# https://github.com/eogit/pyeo/blob/b9f1563913515e53780a19e36cb104f1f2a7364a/pyeo/classification.py#L1111

log.info(f'Model Building Started:')

# initialise an Extra Trees Classifier
model = ens.ExtraTreesClassifier(bootstrap=False, criterion="gini", max_features=0.55, min_samples_leaf=2,
                                    min_samples_split=16, n_estimators=100, n_jobs=-1, class_weight='balanced')

# load signatures from csv file
features, labels = cls.load_signatures(csv_path, sig_datatype=np.int32)

# split into test and train samples, reserving 25% for testing model accuracy
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=.25, random_state=101)

# train the model
model.fit(X_train, y_train)

# confusion matrix
## Example under heiko/matogrosso... mato_rf_toby_1_1.txt

# save the model
model_path = os.path.join(out_dir, model_out_filename)
joblib.dump(model, filename = model_path)

log.info(f"Model saved at {model_path}")
# Out:
# 2023-06-01 17:22:58,555: INFO: Model Building Started:
# 2023-06-01 17:23:00,199: INFO: Model saved at ./models/model_all_bands/AllBands_model.pkl

# %% [markdown]
# ## <a id='toc3_3_'></a>[Accuracy Statistics](#toc0_)

# %% [markdown]
# Now that we have a model trained from shapefiles overlaid a Sentinel-2 image tile, we need to assess the model accuracy.
#
# To do that, we will use the model to predict the classes of `y_test` from the values of `X_test`, which comprise the 25% that we reserved for testing model accuracy.

# %%
log.info(f'Model Performance Analysis Started:')

confusion_matrix_out_filename = f'{model_name}_confusion_matrix.txt'
class_scores_out_filename = f'{model_name}_class_scores.txt'

# make a prediction
y_pred = model.predict(X_test)

# create a confusion matrix
matrix = confusion_matrix(y_true=y_test, y_pred=y_pred,)

# write the confusion matrix to file
with open(os.path.join(out_dir, confusion_matrix_out_filename), "w") as txt:
    print(matrix, file=txt)

# write classification labels
target_names = ["Primary Forest",
          "Bare Soil"]

# target_names = ["Primary Forest",
#           "Plantation Forest",
#           "Bare Soil",
#           "Crops",
#           "Grassland",
#           # "Open Water",
#           "Artificial"]

# view the matrix
print(matrix)

# create classification metrics report
report = classification_report(y_true=y_test, y_pred=y_pred, target_names=target_names)

# write classification report to file
with open(os.path.join(out_dir, class_scores_out_filename), "w") as txt:
    print(report, file=txt)

# view the report
print(report)
# Out:
# 2023-06-01 17:24:50,120: INFO: Model Performance Analysis Started:
# [[ 6459     0]
#  [    9 21097]]
#                 precision    recall  f1-score   support
#
# Primary Forest       1.00      1.00      1.00      6459
#      Bare Soil       1.00      1.00      1.00     21106
#
#       accuracy                           1.00     27565
#      macro avg       1.00      1.00      1.00     27565
#   weighted avg       1.00      1.00      1.00     27565

# %% [markdown]
# ## <a id='toc3_4_'></a>[Image Classification](#toc0_)

# %% [markdown]
# If we are happy with the performance of the model, we can now classify a Sentinel-2 image tile, if we believe the values the model was trained on represent the spectral values of the land cover of the imagery of interest.

# %%
log.info(f'Image Classification with Model Started:')

# test_raster_path = training_raster_path
test_raster_filename = 'composite_T36NXG_20221202T075301_AllBands_test_classifier.tif'
test_raster_path = os.path.join(model_dir, test_raster_filename)

# class_out_filename = f'{model_name}_class.tif'
class_out_filename = f'{test_raster_filename}_full_class.tif'
class_out_path = os.path.join(out_dir, class_out_filename)

cls.classify_image(image_path=test_raster_path,
                   model_path=model_path,
                   class_out_path=class_out_path,
                   prob_out_path=None,
                   apply_mask=False,
                   out_format="GTiff",
                   chunks=10,
                   nodata=0,
                   skip_existing = False)

log.info(f'Classified Image Saved: {class_out_path}')
# Out:
# 2023-06-01 17:26:51,205: INFO: Image Classification with Model Started:
# 2023-06-01 17:26:51,207: INFO: Classifying file: ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_test_classifier.tif
# 2023-06-01 17:26:51,207: INFO: Saved model     : ./models/model_all_bands/AllBands_model.pkl
# 2023-06-01 17:26:51,811: INFO: Proportion of non-missing values: 100.00%
# 2023-06-01 17:26:52,295: INFO:    Number of chunks 10 Chunk size 322746 Chunk residual 6
# 2023-06-01 17:26:52,296: INFO:    Classifying chunk 1 of size 322746
# 2023-06-01 17:26:52,638: INFO:    Classifying chunk 2 of size 322746
# 2023-06-01 17:26:52,929: INFO:    Classifying chunk 3 of size 322746
# 2023-06-01 17:26:53,203: INFO:    Classifying chunk 4 of size 322746
# 2023-06-01 17:26:53,460: INFO:    Classifying chunk 5 of size 322746
# 2023-06-01 17:26:53,748: INFO:    Classifying chunk 6 of size 322746
# 2023-06-01 17:26:54,047: INFO:    Classifying chunk 7 of size 322746
# 2023-06-01 17:26:54,341: INFO:    Classifying chunk 8 of size 322746
# 2023-06-01 17:26:54,635: INFO:    Classifying chunk 9 of size 322746
# 2023-06-01 17:26:54,936: INFO:    Classifying chunk 10 of size 322752
# 2023-06-01 17:26:56,150: INFO: Created classification image file: ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_test_classifier.tif_full_class.tif
# 2023-06-01 17:26:56,179: INFO: Classified Image Saved: ./models/model_all_bands/composite_T36NXG_20221202T075301_AllBands_test_classifier.tif_full_class.tif

# %% [markdown]
# ## <a id='toc3_5_'></a>[Visualise the Classified Imagery](#toc0_)

# %% [markdown]
# Now we can visualise the classified imagery.

# %%
log.info(f'Classified Image Visualisation Started:')

def visualise_classification(classified_path: str, labels: list):

    from osgeo import gdal
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.colors as mcolors

    ds = gdal.Open(classified_path)
    array = np.array(ds.GetRasterBand(1).ReadAsArray())

    counts, _ = np.histogram(array, bins = len(labels))
    print(counts)
    percent = counts / counts.sum()
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 6))


    def discrete_cmap(N, base_cmap=None):
        """Create an N-bin discrete colormap from the specified input map"""

        # this function was taken on 10/03/2023 from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
        # author: Jake Vanderplas

        base = plt.cm.get_cmap(base_cmap)
        color_list = base(np.linspace(0, 1, N))
        cmap_name = base.name + str(N)
        return base.from_list(cmap_name, color_list, N)

    cmap = discrete_cmap(len(labels), base_cmap="coolwarm")
    # cmap = discrete_cmap(len(labels), base_cmap="cubehelix")
    cmap.set_bad("red")
    colour_list = [mcolors.rgb2hex(cmap(i)) for i in range(cmap.N)]

    x = np.arange(1, (len(labels) + 1))
    ax1.bar(x, percent, color=colour_list)
    # ax1.set_xticks(x, labels=labels, rotation=35, ha="right")
    ax1.set_title("Classes distribution")
    ax2.set_title("Classification raster displayed")

    ax2.imshow(array, cmap=cmap, aspect="auto")
    plt.show()

    return
# Out:
# 2023-06-01 17:41:33,130: INFO: Classified Image Visualisation Started:

# %%
# create a list of class labels
labels = [
    "Primary Forest",
    "Bare Soil"]

# labels = [
#     "Primary Forest",
#     "Plantation Forest",
#     "Bare Soil",
#     "Crops",
#     # "Open Water",
#     "Grassland",
#     "Artificial"
#     ]

visualise_classification(classified_path=class_out_path, labels=labels)
# Out:
# [1118994 2108472]

# %% [markdown]
# # Model Training and Classification, in two Functions

# %% [markdown]
# We can also train a Random Forest classifier on multiple Sentinel-2 tiles with multiple training shapefiles. This approach can create a superior classifier because the training shapefiles can cover more tiles, providing the model with a variety of spectral values per class.

# %% [markdown]
# The `create_rf_model_for_region` function assumes the training rasters and training shapefiles are structured like the cell diagram below.
# **Note, the filenames do not need to be a specific format**
#
# The second function will we use is `classify_directory`, which classifies multiple images in one call.

# %%
# model_folder
    # training_raster_tile_1
    # training_shapefile_tile_1
    # training_raster_tile_2
    # training_shapefile_tile_2

# %%
pyeo_home = "/data/clcr/shared/IMPRESS/Ivan/kenya_national_prod"

# %%
out_folder = "models/model_36MYE_37MER_37NCC_20230417"

# %%
# specify the path to the directory structure
region_folder = os.path.join(pyeo_home, out_folder)

# name the model that will be created
model_file = "model_36MYE_37MER_37NCC_Unoptimised_20230417.pkl"
model_path = os.path.join(region_folder, model_file)

cls.create_rf_model_for_region(path_to_region=region_folder,
                               model_out=model_path,
                               attribute="class"
                               #,attribute="CODE" # replace this line with the one above, if training shapefile has CODE as class heading
                               )
# Out:
# 2023-03-31 11:08:25,552: INFO: Create a random forest classification model for region based on tif/shp file pairs: ../models/model_training_1/
# 2023-03-31 11:08:25,557: INFO: Collecting training data from all tif/shp file pairs.
# 2023-03-31 11:08:25,558: INFO: Analysing shapefile: ../models/model_training_1/composite_T36NYF_20221202T075301_clipped.shp
# 2023-03-31 11:08:25,572: INFO: EPSG codes of the image and shapefile: 21097, 21097
# 2023-03-31 11:08:28,270: INFO: This training data shapefile includes 5 classes: [1, 3, 4, 5, 6]
# 2023-03-31 11:08:28,271: INFO: 4 bands in image file
# 2023-03-31 11:08:28,271: INFO: (4, 1588, 1464)
# 2023-03-31 11:08:28,272: INFO: (1588, 1464)
# 2023-03-31 11:08:28,273: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-31 11:08:28,273: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-31 11:08:28,274: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-31 11:08:28,303: INFO: (4, 8448)
# 2023-03-31 11:08:28,303: INFO: (8448,)
# 2023-03-31 11:08:28,304: INFO: 8448 training pixels in shapefile
# 2023-03-31 11:08:28,311: WARNING: composite_T36MYE_20230220T074941_clipped.shp not found. Skipping.
# 2023-03-31 11:08:28,312: INFO: Training data collection complete.
# 2023-03-31 11:08:28,312: INFO: Training pixels by class:
# 2023-03-31 11:08:28,313: INFO:   Class 1 has 5399 training pixels
# 2023-03-31 11:08:28,313: INFO:   Class 3 has 220 training pixels
# 2023-03-31 11:08:28,314: INFO:   Class 4 has 221 training pixels
# 2023-03-31 11:08:28,315: INFO:   Class 5 has 168 training pixels
# 2023-03-31 11:08:28,315: INFO:   Class 6 has 2440 training pixels
# 2023-03-31 11:08:28,316: INFO: Drawing a more balanced random sample of 1680 max. training pixels for each class.
# 2023-03-31 11:08:28,329: INFO: After class balancing, training pixels by class:
# 2023-03-31 11:08:28,330: INFO:   Class 1 has 1680 training pixels
# 2023-03-31 11:08:28,330: INFO:   Class 3 has 220 training pixels
# 2023-03-31 11:08:28,331: INFO:   Class 4 has 221 training pixels
# 2023-03-31 11:08:28,331: INFO:   Class 5 has 168 training pixels
# 2023-03-31 11:08:28,332: INFO:   Class 6 has 1680 training pixels
# 2023-03-31 11:08:28,334: INFO: Saving learning data file: ../models/model_training_1/output/model_from_region_learning.pkl
# 2023-03-31 11:08:28,345: INFO: Saving tab-delimited signature file: ../models/model_training_1/output/model_from_region_signatures.txt
# 2023-03-31 11:08:28,355: INFO: Signatures:
# 2023-03-31 11:08:28,356: INFO: class, band, min, max, mean, stdev
# 2023-03-31 11:08:28,363: INFO: 1, 1, 186, 412, 267.83988095238095, 34.71097311430637
# 2023-03-31 11:08:28,374: INFO: 1, 2, 264, 588, 419.2607142857143, 57.766982822654946
# 2023-03-31 11:08:28,385: INFO: 1, 3, 176, 428, 283.1196428571429, 45.600584563780494
# 2023-03-31 11:08:28,400: INFO: 1, 4, 1698, 4105, 2740.4261904761906, 433.9111946753317
# 2023-03-31 11:08:28,407: WARNING: Class 2 does not exist in the learning data.
# 2023-03-31 11:08:28,413: INFO: 3, 1, 395, 599, 488.75, 38.0685065009728
# 2023-03-31 11:08:28,423: INFO: 3, 2, 639, 902, 752.7318181818182, 53.8901799439936
# 2023-03-31 11:08:28,434: INFO: 3, 3, 739, 1114, 937.2318181818182, 75.96788486541996
# 2023-03-31 11:08:28,444: INFO: 3, 4, 1847, 2522, 2140.8727272727274, 149.22004891131155
# 2023-03-31 11:08:28,455: INFO: 4, 1, 277, 352, 309.43891402714934, 16.94649673361944
# 2023-03-31 11:08:28,466: INFO: 4, 2, 652, 824, 737.710407239819, 34.59633888035431
# 2023-03-31 11:08:28,477: INFO: 4, 3, 295, 440, 354.96380090497735, 35.78850186145612
# 2023-03-31 11:08:28,488: INFO: 4, 4, 3289, 4732, 4171.995475113122, 263.44468968815175
# 2023-03-31 11:08:28,498: INFO: 5, 1, 441, 570, 503.36309523809524, 31.05151709201053
# 2023-03-31 11:08:28,509: INFO: 5, 2, 758, 930, 837.6547619047619, 33.637373728045674
# 2023-03-31 11:08:28,519: INFO: 5, 3, 516, 778, 635.1964285714286, 79.47298406848299
# 2023-03-31 11:08:28,530: INFO: 5, 4, 2685, 4080, 3391.6488095238096, 435.4118174521888
# 2023-03-31 11:08:28,541: INFO: 6, 1, 268, 417, 315.03988095238094, 19.368197039660604
# 2023-03-31 11:08:28,551: INFO: 6, 2, 430, 655, 507.03988095238094, 26.07752139453259
# 2023-03-31 11:08:28,562: INFO: 6, 3, 346, 587, 439.0464285714286, 40.611806996527285
# 2023-03-31 11:08:28,572: INFO: 6, 4, 1319, 2836, 2169.804166666667, 272.70356944904853
# 2023-03-31 11:08:28,581: INFO: Fitting a single random forest model to the training dataset without gridsearch.
# 2023-03-31 11:08:28,839: INFO: Accuracy assessment at model training stage
# 2023-03-31 11:08:28,871: INFO: Training   classification accuracy (75% of data): 1.0
# 2023-03-31 11:08:28,890: INFO: Validation classification accuracy (25% of data): 0.9979859013091642
# 2023-03-31 11:08:28,892: INFO: Confusion matrix:
# 2023-03-31 11:08:28,892: INFO:             Reference class ->
# 2023-03-31 11:08:28,893: INFO:                 |
# 2023-03-31 11:08:28,894: INFO: Predicted class v
# 2023-03-31 11:08:28,894: INFO:
# [[416   0   0   0   1]
#  [  0  56   0   0   0]
#  [  0   0  56   0   0]
#  [  0   0   0  33   0]
#  [  0   1   0   0 430]]
# 2023-03-31 11:08:28,895: INFO: ----------------------------------------
# 2023-03-31 11:08:28,900: INFO: Classification Report
# 2023-03-31 11:08:28,901: INFO:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       417
#            3       0.98      1.00      0.99        56
#            4       1.00      1.00      1.00        56
#            5       1.00      1.00      1.00        33
#            6       1.00      1.00      1.00       431
#
#     accuracy                           1.00       993
#    macro avg       1.00      1.00      1.00       993
# weighted avg       1.00      1.00      1.00       993
#
# 2023-03-31 11:08:28,901: INFO: Saving classification report to /lustre/alice3/data/clcr/shared/IMPRESS/matt/pyeo/notebooks/../models/model_training_1/output/class_scores.txt
# 2023-03-31 11:08:28,953: INFO: Feature ranking:
# 2023-03-31 11:08:28,954: INFO: 1. feature 2 (0.367689)
# 2023-03-31 11:08:28,954: INFO: 2. feature 1 (0.305934)
# 2023-03-31 11:08:28,955: INFO: 3. feature 3 (0.198361)
# 2023-03-31 11:08:28,955: INFO: 4. feature 0 (0.128016)

# %%
# view classification report metrics
with open(f"{os.path.join(pyeo_home, out_folder)}{os.sep}class_scores.txt", "r") as report:
    print(report.read())
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       417
#            3       0.98      1.00      0.99        56
#            4       1.00      1.00      1.00        56
#            5       1.00      1.00      1.00        33
#            6       1.00      1.00      1.00       431
#
#     accuracy                           1.00       993
#    macro avg       1.00      1.00      1.00       993
# weighted avg       1.00      1.00      1.00       993

# %% [markdown]
# As of yet, we have not written a function for `pyeo` to take user-supplied class names, which would enable class names to be displayed in the classification metrics report above.
#
# Therefore, currently users should substitute their own class names to pass to the classification report function.

# %% [markdown]
# ## <a id='toc4_1_'></a>[Classify Directory](#toc0_)

# %% [markdown]
# `cls.classify_directory` requires the `class_out_dir` to already exist, so make sure that this directory is present before running the function.

# %%
# provide the path of the directory of images to classify
image_directory = pyeo_home

# provide the path of the classified output folder
class_out_dir = f"{os.path.join(pyeo_home, out_folder)}{os.sep}"

# run the function to classify the directory of images you provided
cls.classify_directory(in_dir=image_directory,
                       model_path=model_path,
                       class_out_dir=class_out_dir,
                       chunks=10)
# Out:
# 2023-03-31 11:37:20,430: INFO: Classifying files in ../models/model_training_1/
# 2023-03-31 11:37:20,431: INFO: Class files saved in ../models/model_training_1/output/
# 2023-03-31 11:37:20,432: INFO: Classifying file: ../models/model_training_1/composite_T36NYF_20221202T075301_clipped.tif
# 2023-03-31 11:37:20,433: INFO: Saved model     : ../models/model_training_1/output/model_from_region.pkl
# 2023-03-31 11:37:20,605: INFO: Proportion of non-missing values: 100.00%
# 2023-03-31 11:37:20,722: INFO:    Number of chunks 10 Chunk size 232483 Chunk residual 2
# 2023-03-31 11:37:20,722: INFO:    Classifying chunk 1 of size 232483
# 2023-03-31 11:37:22,297: INFO:    Classifying chunk 2 of size 232483
# 2023-03-31 11:37:23,845: INFO:    Classifying chunk 3 of size 232483
# 2023-03-31 11:37:25,318: INFO:    Classifying chunk 4 of size 232483
# 2023-03-31 11:37:26,794: INFO:    Classifying chunk 5 of size 232483
# 2023-03-31 11:37:28,346: INFO:    Classifying chunk 6 of size 232483
# 2023-03-31 11:37:29,901: INFO:    Classifying chunk 7 of size 232483
# 2023-03-31 11:37:31,391: INFO:    Classifying chunk 8 of size 232483
# 2023-03-31 11:37:32,919: INFO:    Classifying chunk 9 of size 232483
# 2023-03-31 11:37:34,439: INFO:    Classifying chunk 10 of size 232485
# 2023-03-31 11:37:36,614: INFO: Created classification image file: ../models/model_training_1/output/composite_T36NYF_20221202T075301_clipped_class.tif
# 2023-03-31 11:37:36,636: INFO: Classifying file: ../models/model_training_1/composite_T36MYE_20230220T074941_clipped.tif
# 2023-03-31 11:37:36,636: INFO: Saved model     : ../models/model_training_1/output/model_from_region.pkl
# 2023-03-31 11:37:36,836: INFO: Proportion of non-missing values: 100.00%
# 2023-03-31 11:37:36,965: INFO:    Number of chunks 10 Chunk size 265194 Chunk residual 6
# 2023-03-31 11:37:36,966: INFO:    Classifying chunk 1 of size 265194
# 2023-03-31 11:37:38,706: INFO:    Classifying chunk 2 of size 265194
# 2023-03-31 11:37:40,404: INFO:    Classifying chunk 3 of size 265194
# 2023-03-31 11:37:42,093: INFO:    Classifying chunk 4 of size 265194
# 2023-03-31 11:37:43,723: INFO:    Classifying chunk 5 of size 265194
# 2023-03-31 11:37:45,325: INFO:    Classifying chunk 6 of size 265194
# 2023-03-31 11:37:46,972: INFO:    Classifying chunk 7 of size 265194
# 2023-03-31 11:37:48,597: INFO:    Classifying chunk 8 of size 265194
# 2023-03-31 11:37:50,178: INFO:    Classifying chunk 9 of size 265194
# 2023-03-31 11:37:51,737: INFO:    Classifying chunk 10 of size 265200
# 2023-03-31 11:37:53,987: INFO: Created classification image file: ../models/model_training_1/output/composite_T36MYE_20230220T074941_clipped_class.tif

# %% [markdown]
# ## <a id='toc4_2_'></a>[Visualise the Classifications](#toc0_)

# %% [markdown]
# Here, we can visualise the images we have just classified. Just pass the filename of the classified image.

# %%
# specify the directory of a classified image
classified_path = f"{class_out_dir}/composite_T36NYF_20221202T075301_clipped_class.tif"

# create a list of class labels. In this example we have more classes because the additional classes were delineated to train this region rf model.
labels = [
    "Primary Forest",
    "Plantation Forest",
    "Bare Soil",
    "Crops",
    "Grassland",
    "Open Water",
    "Artificial"
]

visualise_classification(classified_path=classified_path, labels=labels)
# Out:
# [872429      0 167086      0 243031 819771 222515]

# %%
# specify the directory of a classified image
classified_path = f"{class_out_dir}/composite_T36MYE_20230220T074941_clipped_class.tif"

visualise_classification(classified_path=classified_path, labels=labels)
# Out:
# [1723112       0   79287       0  511502  171635  166410]
